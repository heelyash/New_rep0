# %%
# prompt: create miss u word in  animated plot using libary

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# Create the figure and axes object
fig, ax = plt.subplots()

# Set the limits of the plot
ax.set_xlim(0, 10)
ax.set_ylim(0, 1)

# Text to display
text = "miss u"

# Create the text object
txt = ax.text(5, 0.5, text, ha='center', va='center', fontsize=20)

# Define the animation function
def animate(i):
    # Rotate the text
    txt.set_rotation(i)
    return txt,

# Create the animation
ani = animation.FuncAnimation(fig, animate, frames=360, interval=20, blit=True)

# Display the animation
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py:892: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
